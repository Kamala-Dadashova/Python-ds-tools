# %%
# %%writefile myfile.txt
# Hello!This is a text file
# This is the second line
# This is the third line
# Out:
# Overwriting myfile.txt

# %%
myfile=open("myfile.txt")

# %%
pwd
# Out:
# '/content'

# %%
myfile.read()
# Out:
# 'Hello!This is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# This happens because you can imagine the reading "cursor" is at the end of the file after having read it. So there is nothing left to read. We can reset the "cursor" like this

# %%
# Seek to the start of file (index 0)
myfile.seek(0)
# Now read again
myfile.read()
# Out:
# 'Hello!This is a text file\nThis is the second line\nThis is the third line\n'

# %%
# Readlines returns a list of the lines in the file
myfile.seek(0)
myfile.readlines()
# Out:
# ['Hello!This is a text file\n',
#  'This is the second line\n',
#  'This is the third line\n']

# %%
myfile.close()

# %%
with open("myfile.txt") as my_new_file:# You do not have to close the file with this methods
  print(my_new_file.read())
# Out:
# Hello!This is a text file
# This is the second line
# This is the third line

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Writing my_new_file.txt

# %%
with open("my_new_file.txt", mode='r') as f:
  print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open("my_new_file.txt", mode='a') as f:
   f.write('\nFOUR ON FOURTH')

# %%
with open("my_new_file.txt", mode='r') as f:
  print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
#
# FOUR ON FOURTH

# %%
with open('second.txt', mode='w') as f: #file does not exist we create and write on it
  f.write('I created this file')

# %%
with open('second.txt', mode='r') as f: #file does not exist we create and write on it
  print(f.read())
# Out:
# I created this file
